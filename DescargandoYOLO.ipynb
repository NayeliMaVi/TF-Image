# %%
# !pip install roboflow
#usaremos un modelo pre entrenado
from roboflow import Roboflow
rf = Roboflow(api_key="l1TKpQcSgjUpUyuOUQuf")
project = rf.workspace("thanya").project("sitting-posture-1xswj")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.42, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to sitting-posture-1 in yolov8:: 100%|██████████| 320/320 [00:00<00:00, 1231.88it/s]

# %%
# !pip install ultralytics==8.0.196
# si nos especifica que version usar
# Out:
# ...
#    ---------------------------------------- 0.0/631.1 kB ? eta -:--:--
#    ------ --------------------------------- 102.4/631.1 kB 2.0 MB/s eta 0:00:01
#    -------------- ------------------------- 235.5/631.1 kB 2.4 MB/s eta 0:00:01
#    --------------------------------- ------ 532.5/631.1 kB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 631.1/631.1 kB 4.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.2.42
#     Uninstalling ultralytics-8.2.42:
#       Successfully uninstalled ultralytics-8.2.42
# ...

# %%
import os
import ultralytics
model = ultralytics.YOLO("yolov8n.yaml")

# %%
# entrenando
#cambiar la ruta xd
results= model.train(data=os.path.join("D:\\VS\\TF-PI\\sitting-posture-1","data.yaml"), epochs=100)
# Out:
# New https://pypi.org/project/ultralytics/8.2.45 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196  Python-3.8.0 torch-2.3.1+cpu CPU (Intel Core(TM) i7-10750H 2.60GHz)
# ...

# %%
#Probando y se crea una nueva carpeta que salen resultados
#cambiar la ruta xd
waos=model.val(data=os.path.join("D:\\VS\\TF-PI\\sitting-posture-1", "data.yaml"))
# Out:
# Ultralytics YOLOv8.0.196  Python-3.8.0 torch-2.3.1+cpu CPU (Intel Core(TM) i7-10750H 2.60GHz)
# val: Scanning D:\VS\TF-PI\sitting-posture-1\valid\labels.cache... 5 images, 0 backgrounds, 0 corrupt: 100%|██████████| 5/5 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.92it/s]
#                    all          5          6       0.35      0.375      0.503      0.235
#                    bad          5          2      0.214        0.5      0.514      0.301
#                   good          5          4      0.486       0.25      0.493      0.169
# Speed: 2.4ms preprocess, 94.7ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs\detect\val5
